# %% [markdown]
# # Python Collections: An Introduction
#
# This notebook explores fundamental Python collection types: Lists, Tuples, Sets, and Dictionaries. These data structures are essential for organizing and manipulating data efficiently in Python.
#
# # Python Collections
#
#
# *   List
# *   Tuple
# *   sets
# *   dict

# %% [markdown]
# # List in Python
#
# Lists are ordered, mutable collections of items in Python.
# They can store diverse data types and are defined using square brackets `[]`.

# %% [markdown]
# #List Function
#
#
#
# *   Append()
# *   Insert()
# *   pop()
# *   count()
# *   extend()
# *   clear()
# *   Inital

# %%
my_list = ['apple', 'banana', 'cherry', 'date']


print(f"First element: {my_list[0]}")
print(f"Second element: {my_list[1]}")


print(f"Last element: {my_list[-1]}")
print(f"Second to last element: {my_list[-2]}")
# Out:
# First element: apple
# Second element: banana
# Last element: date
# Second to last element: cherry

# %%
name = "Khan"
print(name , type(name))
# Add a Value
len(name)
# Out:
# Khan <class 'str'>
# 4

# %%
course = ['AI and DS'," Web and App Dev", "Graphic Desiging", "Digital Marketing", "Flutter dev"]
len(course)
# Out:
# 5

# %%
course.append("Agentic Ai")
course
# Out:
# ['AI and DS',
#  ' Web and App Dev',
#  'Graphic Desiging',
#  'Digital Marketing',
#  'Flutter dev',
#  'Agentic Ai',
#  'Agentic Ai']

# %%
course.pop(1)
course
# Out:
# ['AutoCAD',
#  ' Web and App Dev',
#  'Graphic Desiging',
#  'Ethical Hacking',
#  'Digital Marketing',
#  'Flutter dev',
#  'Agentic Ai',
#  'Agentic Ai']

# %%
course.insert(0,"AutoCAD")
course.insert(4,"Ethical Hacking")
course
# Out:
# ['AutoCAD',
#  'AutoCAD',
#  ' Web and App Dev',
#  'Graphic Desiging',
#  'Ethical Hacking',
#  'Ethical Hacking',
#  'Digital Marketing',
#  'Flutter dev',
#  'Agentic Ai',
#  'Agentic Ai']

# %%
course.count("b")
# Out:
# 0

# %%
course.extend(["Java","React", "Javascript"])
course
# Out:
# ['AutoCAD',
#  'AutoCAD',
#  ' Web and App Dev',
#  'Graphic Desiging',
#  'Ethical Hacking',
#  'Ethical Hacking',
#  'Digital Marketing',
#  'Flutter dev',
#  'Agentic Ai',
#  'Agentic Ai',
#  'Java',
#  'React',
#  'Javascript']

# %%
len(course)
# Out:
# 13

# %%
a = [10, 20,30,40,50]
a
# Out:
# [10, 20, 30, 40, 50]

# %%
a.clear()

# %%
a
# Out:
# []

# %%
a = [10, 20,30,40,50]
a
# Out:
# [10, 20, 30, 40, 50]

# %%
a.index(20)
# Out:
# 1

# %%
b = [10,20,40,30,20,30]
a.extend(b)
a
# Out:
# [10, 20, 30, 40, 50, 10, 20, 40, 30, 20, 30]

# %%
a
# Out:
# [10, 20, 30, 40, 50, 10, 20, 40, 30, 20, 30]

# %%
a.count(20)
# Out:
# 3

# %%
a.count(10)
# Out:
# 2

# %%
a.count(40)
# Out:
# 2

# %%
a.sort()
a
# Out:
# [10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 50]

# %%
a.sort(reverse=True)
a
# Out:
# [50, 40, 40, 30, 30, 30, 20, 20, 20, 10, 10]

# %%
a.reverse()
a
# Out:
# [10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 50]

# %%
a.sort()
a
# Out:
# [10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 50]

# %%
a
# Out:
# [10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 50]

# %%
a.reverse()
a
# Out:
# [50, 40, 40, 30, 30, 30, 20, 20, 20, 10, 10]

# %%
b
# Out:
# [10, 20, 40, 30, 20, 30]

# %%
c = a.copy()
c
# Out:
# [50, 40, 40, 30, 30, 30, 20, 20, 20, 10, 10]

# %%
c.sort()
c
# Out:
# [10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 50]

# %%
c.append(5)

# %%
c
# Out:
# [10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 50, 5]

# %%
sum(c)
d = [10,10,20,10,10,1000]
sum(d)
# Out:
# 1060

# %%
print(max(a))
print(max(b))
print(max(c))
print(max(d))
# Out:
# 50
# 40
# 50
# 1000

# %%
print(min(a))
print(min(b))
print(min(c))
print(min(d))
# Out:
# 10
# 10
# 5
# 10

# %%
new_list = sorted(d)
new_list
# Out:
# [10, 20, 1000]

# %%
d.remove(10)

# %%
print(f"New_list new Value is {new_list}")
print(f"D new Value is {d}")
# Out:
# New_list new Value is [10, 10, 10, 10, 20, 1000]
# D new Value is [20, 10, 1000]

# %%
d.remove(10)

# %%
d.remove(10)

# %%
text = "Hello"
result = list(text)
result
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
t = (1, 2, 3)

print(list(t))
# Out:
# [1, 2, 3]
