# %% [markdown]
# # Python Collections: An Introduction
#
# This notebook explores fundamental Python collection types: Lists, Tuples, Sets, and Dictionaries. These data structures are essential for organizing and manipulating data efficiently in Python.
#
# # Python Collections
#
#
# *   List
# *   Tuple
# *   sets
# *   dict

# %% [markdown]
# #Tuple in Python

# %% [markdown]
# Tuples are ordered, immutable collections of items. They are similar to lists but cannot be modified after creation. Tuples are often used to store heterogeneous data (different data types) and are typically created with parentheses `()`. Due to their immutability, they can be used as keys in dictionaries and elements in sets.

# %%
# This is a string not a tuple you write a like and then tuple "Hello", this a Tuple
a = ("hello") #
type(a)
# Out:
# str

# %% [markdown]
# #Tuple Type chchk
#
# - chck the type of tuple
# - print the tuple

# %%
name = ("hamza", "Raza", "ALi","Rehman",12.12,True,100)
print(type(name))
name
# Out:
# <class 'tuple'>
# ('hamza', 'Raza', 'ALi', 'Rehman', 12.12, True, 100)

# %% [markdown]
# #Count Function in Tuple
#
# - Run the count() function
# - Chck the any num is how much times and Print
# - print the 4 Values 0,1,4,2 kitni bar ayi
# - print and show

# %%
nums = (10, 0, 2, 3, 41, 1, 2, 3, 4, 6, 3, 2, 1, 2, 2)

# %%
print(f"""
0 Kitni bar aya hai is Variable ma : {nums.count(0)}
1 Kitni bar aya hai is Variable ma : {nums.count(1)}
4 Kitni bar aya hai is Variable ma : {nums.count(4)}
2 Kitni bar aya hai is Variable ma : {nums.count(2)}
""")
# Out:
# 0 Kitni bar aya hai is Tuple ma : 1
# 1 Kitni bar aya hai is Tuple ma : 2
# 4 Kitni bar aya hai is Tuple ma : 1
# 2 Kitni bar aya hai is Tuple ma : 5

# %%
nums.count(10)
# Out:
# 1
